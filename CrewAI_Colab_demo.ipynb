# %% [markdown]
# <a href="https://colab.research.google.com/github/taruchit/CrewAI/blob/main/CrewAI_Colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# %%
# !uv tool install crewai
# Out:
# `crewai` is already installed

# %%
# !uv tool run crewai create crew hello_world
# Out:
# Folder hello_world already exists. Do you want to override it? [y/N]: y
# Overriding folder hello_world...
# Creating folder hello_world...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. huggingface
# 7. ollama
# 8. watson
# 9. bedrock
# 10. azure
# 11. cerebras
# 12. sambanova
# 13. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Select a model to use for Openai:
# 1. gpt-4
# 2. gpt-4.1
# 3. gpt-4.1-mini-2025-04-14
# 4. gpt-4.1-nano-2025-04-14
# 5. gpt-4o
# 6. gpt-4o-mini
# 7. o1-mini
# 8. o1-preview
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Enter your OPENAI API key (press Enter to skip):
# API keys and model saved to .env file
# Selected model: gpt-4.1-mini-2025-04-14
#   - Created hello_world/.gitignore
#   - Created hello_world/pyproject.toml
#   - Created hello_world/README.md
#   - Created hello_world/knowledge/user_preference.txt
# ...

# %%
# %cd /content/hello_world
# Out:
# /content/hello_world

# %%
# !uv tool run crewai run
# Out:
# Running the Crew
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 3b84c2d9-8c58-471e-9533-ff5583ef8b14                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# ...
